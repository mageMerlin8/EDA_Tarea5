# %%
# %%capture
# %run BST.ipynb, pruebas.ipynb

# %%
def createTree():
    miarbol = ArbolB()
    miarbol.insert(70)
    miarbol.insert(50)
    miarbol.insert(100)
    miarbol.insert(30)
    miarbol.insert(60)
    miarbol.insert(80)
    miarbol.insert(115)
    miarbol.insert(20)
    miarbol.insert(40)
    miarbol.insert(65)
    miarbol.insert(75)
    miarbol.insert(87)
    miarbol.insert(112)
    miarbol.insert(35)
    miarbol.insert(63)
    miarbol.insert(68)
    miarbol.insert(67)
    return miarbol

# %%
miarbol = createTree()

miarbol.draw()

# %%
miarbol.delete(70)
miarbol.draw()

# %%
miarbol.delete(80)
miarbol.draw()

# %%
miarbol.delete(100)
miarbol.draw()

# %%
miarbol.delete(50)
miarbol.draw()

# %%
print(miarbol)
miarbol.draw()
# Out:
# Árbol: nivel: 0 dato:75
# Nodo Derecho  :
# 	nivel: 1 dato:112
# 	Nodo Derecho  :
# 		nivel: 2 dato:115
#
# 	Nodo Izquierdo:
# 		nivel: 2 dato:87
#
# Nodo Izquierdo:
# 	nivel: 1 dato:60
# 	Nodo Derecho  :
# 		nivel: 2 dato:65
# 		Nodo Derecho  :
# 			nivel: 3 dato:68
# 			Nodo Izquierdo:
# 				nivel: 4 dato:67
#
# 		Nodo Izquierdo:
# 			nivel: 3 dato:63
#
# 	Nodo Izquierdo:
# 		nivel: 2 dato:30
# 		Nodo Derecho  :
# 			nivel: 3 dato:40
# 			Nodo Izquierdo:
# 				nivel: 4 dato:35
#
# 		Nodo Izquierdo:
# 			nivel: 3 dato:20
